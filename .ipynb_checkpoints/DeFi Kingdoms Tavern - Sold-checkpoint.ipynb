# %%
import time
import datetime
import requests
import json
import pandas as pd

import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

import chart_studio.plotly as py
import plotly.express as px
import plotly.graph_objects as go
import cufflinks as cf

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <function cufflinks.offline.go_offline(connected=None)>

# %%
#query = """query {
#    saleAuction(id: 2328) {
#    id
#    endedAt
#    endingPrice
#    }
#}"""

query = """query {
  saleAuctions(first:1000 orderBy: endedAt orderDirection: desc 
  		where: {
        open: false
        purchasePrice_not: null
      }
  		
  
  		) {
    id
    tokenId {
      id
      rarity
      generation
      mainClass
      subClass
      statBoost1
      statBoost2
      profession
      summons
      maxSummons
    }
  	endedAt
    purchasePrice
  }
}
"""

url = "https://graph.defikingdoms.com/subgraphs/name/defikingdoms/apiv5"
r = requests.post(url, json={"query": query})

# %%
if r.status_code == 200:
    print(json.dumps(r.json(), indent=2))
else:
    raise Exception(f"Query failed to run with a {r.status_code}.")
# Out:
# {
#   "data": {
#     "saleAuctions": [
#       {
#         "endedAt": "1636166259",
#         "id": "13449",
#         "purchasePrice": "195000000000000000000",
#         "tokenId": {
#           "generation": 4,
#           "id": "11450",
#           "mainClass": "Monk",
#           "maxSummons": 4,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "STR",
#           "statBoost2": "VIT",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636166120",
#         "id": "13368",
#         "purchasePrice": "194000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11658",
#           "mainClass": "Pirate",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "LCK",
#           "statBoost2": "WIS",
#           "subClass": "Thief",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165776",
#         "id": "7901",
#         "purchasePrice": "888000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "9527",
#           "mainClass": "Knight",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 3,
#           "statBoost1": "WIS",
#           "statBoost2": "INT",
#           "subClass": "Thief",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165675",
#         "id": "13304",
#         "purchasePrice": "249000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "7653",
#           "mainClass": "Priest",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "WIS",
#           "statBoost2": "VIT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165668",
#         "id": "13543",
#         "purchasePrice": "210000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "10975",
#           "mainClass": "Priest",
#           "maxSummons": 9,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "AGI",
#           "statBoost2": "STR",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165624",
#         "id": "13573",
#         "purchasePrice": "1299000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11700",
#           "mainClass": "Monk",
#           "maxSummons": 9,
#           "profession": "mining",
#           "rarity": 4,
#           "statBoost1": "END",
#           "statBoost2": "END",
#           "subClass": "Wizard",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165548",
#         "id": "13224",
#         "purchasePrice": "650000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11617",
#           "mainClass": "Monk",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 3,
#           "statBoost1": "VIT",
#           "statBoost2": "LCK",
#           "subClass": "Wizard",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165521",
#         "id": "13369",
#         "purchasePrice": "649000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11430",
#           "mainClass": "Priest",
#           "maxSummons": 2,
#           "profession": "mining",
#           "rarity": 3,
#           "statBoost1": "INT",
#           "statBoost2": "STR",
#           "subClass": "Warrior",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165487",
#         "id": "13575",
#         "purchasePrice": "169990000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11803",
#           "mainClass": "Archer",
#           "maxSummons": 9,
#           "profession": "foraging",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "WIS",
#           "subClass": "Wizard",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165435",
#         "id": "13235",
#         "purchasePrice": "649000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11196",
#           "mainClass": "Archer",
#           "maxSummons": 3,
#           "profession": "fishing",
#           "rarity": 3,
#           "statBoost1": "VIT",
#           "statBoost2": "AGI",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165402",
#         "id": "13532",
#         "purchasePrice": "630000000000000000000",
#         "tokenId": {
#           "generation": 4,
#           "id": "11071",
#           "mainClass": "Archer",
#           "maxSummons": 4,
#           "profession": "mining",
#           "rarity": 3,
#           "statBoost1": "LCK",
#           "statBoost2": "INT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165347",
#         "id": "13306",
#         "purchasePrice": "300000000000000000000",
#         "tokenId": {
#           "generation": 4,
#           "id": "11315",
#           "mainClass": "Archer",
#           "maxSummons": 4,
#           "profession": "gardening",
#           "rarity": 2,
#           "statBoost1": "INT",
#           "statBoost2": "VIT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165324",
#         "id": "13457",
#         "purchasePrice": "286000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "10700",
#           "mainClass": "Thief",
#           "maxSummons": 2,
#           "profession": "mining",
#           "rarity": 2,
#           "statBoost1": "END",
#           "statBoost2": "LCK",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165296",
#         "id": "13383",
#         "purchasePrice": "280000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "10873",
#           "mainClass": "Monk",
#           "maxSummons": 4,
#           "profession": "mining",
#           "rarity": 2,
#           "statBoost1": "INT",
#           "statBoost2": "WIS",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636165257",
#         "id": "13448",
#         "purchasePrice": "206000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "6047",
#           "mainClass": "Warrior",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "WIS",
#           "statBoost2": "WIS",
#           "subClass": "Archer",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636165238",
#         "id": "13557",
#         "purchasePrice": "165000000000000000000",
#         "tokenId": {
#           "generation": 4,
#           "id": "11639",
#           "mainClass": "Monk",
#           "maxSummons": 3,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "LCK",
#           "statBoost2": "DEX",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636164855",
#         "id": "13455",
#         "purchasePrice": "190000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11651",
#           "mainClass": "Wizard",
#           "maxSummons": 9,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "AGI",
#           "subClass": "Priest",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636164412",
#         "id": "13501",
#         "purchasePrice": "190000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11800",
#           "mainClass": "Monk",
#           "maxSummons": 9,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "END",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636164283",
#         "id": "13462",
#         "purchasePrice": "165000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "10580",
#           "mainClass": "Pirate",
#           "maxSummons": 7,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "AGI",
#           "subClass": "Wizard",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636163978",
#         "id": "12294",
#         "purchasePrice": "344000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "7644",
#           "mainClass": "Wizard",
#           "maxSummons": 4,
#           "profession": "mining",
#           "rarity": 2,
#           "statBoost1": "DEX",
#           "statBoost2": "END",
#           "subClass": "Wizard",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636163933",
#         "id": "13322",
#         "purchasePrice": "499000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "10533",
#           "mainClass": "Knight",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "AGI",
#           "statBoost2": "LCK",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636163678",
#         "id": "13546",
#         "purchasePrice": "175000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11829",
#           "mainClass": "Archer",
#           "maxSummons": 9,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "STR",
#           "statBoost2": "AGI",
#           "subClass": "Archer",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636163496",
#         "id": "13540",
#         "purchasePrice": "100000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "6812",
#           "mainClass": "Monk",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "LCK",
#           "statBoost2": "WIS",
#           "subClass": "Warrior",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636163358",
#         "id": "13333",
#         "purchasePrice": "800000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11392",
#           "mainClass": "Ninja",
#           "maxSummons": 5,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "LCK",
#           "statBoost2": "LCK",
#           "subClass": "Thief",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636163279",
#         "id": "13110",
#         "purchasePrice": "295000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "3524",
#           "mainClass": "Pirate",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "AGI",
#           "statBoost2": "DEX",
#           "subClass": "Priest",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636163247",
#         "id": "13502",
#         "purchasePrice": "300000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "9287",
#           "mainClass": "Knight",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "LCK",
#           "statBoost2": "VIT",
#           "subClass": "Warrior",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636163051",
#         "id": "13493",
#         "purchasePrice": "180000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11767",
#           "mainClass": "Warrior",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "WIS",
#           "subClass": "Thief",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636163017",
#         "id": "13496",
#         "purchasePrice": "234000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11286",
#           "mainClass": "Warrior",
#           "maxSummons": 9,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "WIS",
#           "statBoost2": "DEX",
#           "subClass": "Archer",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636162626",
#         "id": "13243",
#         "purchasePrice": "800000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11533",
#           "mainClass": "Paladin",
#           "maxSummons": 5,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "VIT",
#           "statBoost2": "LCK",
#           "subClass": "Priest",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636162392",
#         "id": "13518",
#         "purchasePrice": "110000000000000000000",
#         "tokenId": {
#           "generation": 4,
#           "id": "11071",
#           "mainClass": "Archer",
#           "maxSummons": 4,
#           "profession": "mining",
#           "rarity": 3,
#           "statBoost1": "LCK",
#           "statBoost2": "INT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636162336",
#         "id": "13487",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "7065",
#           "mainClass": "Thief",
#           "maxSummons": 8,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "AGI",
#           "statBoost2": "DEX",
#           "subClass": "Wizard",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636162194",
#         "id": "13456",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11661",
#           "mainClass": "Pirate",
#           "maxSummons": 9,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "LCK",
#           "statBoost2": "VIT",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636162021",
#         "id": "13491",
#         "purchasePrice": "273000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "10088",
#           "mainClass": "Priest",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 2,
#           "statBoost1": "LCK",
#           "statBoost2": "DEX",
#           "subClass": "Paladin",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636161635",
#         "id": "12553",
#         "purchasePrice": "326980000000000000000",
#         "tokenId": {
#           "generation": 4,
#           "id": "10487",
#           "mainClass": "Warrior",
#           "maxSummons": 4,
#           "profession": "gardening",
#           "rarity": 2,
#           "statBoost1": "STR",
#           "statBoost2": "DEX",
#           "subClass": "Warrior",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636161502",
#         "id": "13459",
#         "purchasePrice": "180000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11181",
#           "mainClass": "Thief",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "VIT",
#           "statBoost2": "WIS",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636161479",
#         "id": "13495",
#         "purchasePrice": "178000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "7657",
#           "mainClass": "Thief",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "LCK",
#           "statBoost2": "VIT",
#           "subClass": "Thief",
#           "summons": 4
#         }
#       },
#       {
#         "endedAt": "1636161172",
#         "id": "13485",
#         "purchasePrice": "210000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "11739",
#           "mainClass": "Wizard",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "LCK",
#           "statBoost2": "WIS",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636161170",
#         "id": "13452",
#         "purchasePrice": "230000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "9685",
#           "mainClass": "Wizard",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 0,
#           "statBoost1": "DEX",
#           "statBoost2": "WIS",
#           "subClass": "Warrior",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636160936",
#         "id": "13409",
#         "purchasePrice": "178000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11742",
#           "mainClass": "Wizard",
#           "maxSummons": 6,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "DEX",
#           "subClass": "Monk",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636160714",
#         "id": "13474",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "6268",
#           "mainClass": "Wizard",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "STR",
#           "statBoost2": "INT",
#           "subClass": "Thief",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636160572",
#         "id": "13437",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "6601",
#           "mainClass": "Monk",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "VIT",
#           "statBoost2": "LCK",
#           "subClass": "Priest",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636160536",
#         "id": "13472",
#         "purchasePrice": "150000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "7657",
#           "mainClass": "Thief",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "LCK",
#           "statBoost2": "VIT",
#           "subClass": "Thief",
#           "summons": 4
#         }
#       },
#       {
#         "endedAt": "1636160354",
#         "id": "12779",
#         "purchasePrice": "500000000000000000000",
#         "tokenId": {
#           "generation": 4,
#           "id": "10585",
#           "mainClass": "DarkKnight",
#           "maxSummons": 3,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "LCK",
#           "statBoost2": "AGI",
#           "subClass": "Thief",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636160029",
#         "id": "13464",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "6077",
#           "mainClass": "Warrior",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "END",
#           "statBoost2": "DEX",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636159972",
#         "id": "13463",
#         "purchasePrice": "500000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11231",
#           "mainClass": "Archer",
#           "maxSummons": 2,
#           "profession": "gardening",
#           "rarity": 4,
#           "statBoost1": "STR",
#           "statBoost2": "VIT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636159602",
#         "id": "13215",
#         "purchasePrice": "220000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11488",
#           "mainClass": "Wizard",
#           "maxSummons": 6,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "STR",
#           "subClass": "Summoner",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636159449",
#         "id": "13220",
#         "purchasePrice": "239000000000000000000",
#         "tokenId": {
#           "generation": 4,
#           "id": "11390",
#           "mainClass": "Priest",
#           "maxSummons": 7,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "DEX",
#           "statBoost2": "WIS",
#           "subClass": "Archer",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636158934",
#         "id": "13444",
#         "purchasePrice": "193000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11376",
#           "mainClass": "Pirate",
#           "maxSummons": 8,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "VIT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636158849",
#         "id": "13417",
#         "purchasePrice": "180000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "10074",
#           "mainClass": "Priest",
#           "maxSummons": 9,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "END",
#           "statBoost2": "LCK",
#           "subClass": "Monk",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636158704",
#         "id": "13315",
#         "purchasePrice": "500000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11666",
#           "mainClass": "Paladin",
#           "maxSummons": 5,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "END",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636158624",
#         "id": "13307",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11336",
#           "mainClass": "Monk",
#           "maxSummons": 6,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "DEX",
#           "subClass": "Wizard",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636158530",
#         "id": "13385",
#         "purchasePrice": "185000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11187",
#           "mainClass": "Monk",
#           "maxSummons": 9,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "END",
#           "statBoost2": "VIT",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636157334",
#         "id": "13382",
#         "purchasePrice": "205000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "7296",
#           "mainClass": "Wizard",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "END",
#           "statBoost2": "END",
#           "subClass": "Wizard",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636157271",
#         "id": "13391",
#         "purchasePrice": "179000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11376",
#           "mainClass": "Pirate",
#           "maxSummons": 8,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "VIT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636157208",
#         "id": "13146",
#         "purchasePrice": "276980000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "4107",
#           "mainClass": "Pirate",
#           "maxSummons": 9,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "STR",
#           "statBoost2": "STR",
#           "subClass": "Warrior",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636157101",
#         "id": "13394",
#         "purchasePrice": "45000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "8740",
#           "mainClass": "Knight",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "STR",
#           "statBoost2": "DEX",
#           "subClass": "Knight",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636157101",
#         "id": "13208",
#         "purchasePrice": "210000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11598",
#           "mainClass": "Thief",
#           "maxSummons": 7,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "END",
#           "statBoost2": "STR",
#           "subClass": "Archer",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636156918",
#         "id": "12106",
#         "purchasePrice": "875000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "3731",
#           "mainClass": "Ninja",
#           "maxSummons": 5,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "STR",
#           "statBoost2": "VIT",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636156760",
#         "id": "13232",
#         "purchasePrice": "273000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "10984",
#           "mainClass": "Warrior",
#           "maxSummons": 7,
#           "profession": "gardening",
#           "rarity": 1,
#           "statBoost1": "WIS",
#           "statBoost2": "WIS",
#           "subClass": "Archer",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636156739",
#         "id": "13250",
#         "purchasePrice": "220000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "4780",
#           "mainClass": "Wizard",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "STR",
#           "statBoost2": "VIT",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636156703",
#         "id": "13296",
#         "purchasePrice": "220000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "11616",
#           "mainClass": "Monk",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "END",
#           "statBoost2": "DEX",
#           "subClass": "Warrior",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636155855",
#         "id": "12930",
#         "purchasePrice": "225000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11117",
#           "mainClass": "Warrior",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "WIS",
#           "statBoost2": "INT",
#           "subClass": "Ninja",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636155785",
#         "id": "13344",
#         "purchasePrice": "600000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11112",
#           "mainClass": "Monk",
#           "maxSummons": 8,
#           "profession": "mining",
#           "rarity": 3,
#           "statBoost1": "DEX",
#           "statBoost2": "INT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636155775",
#         "id": "13086",
#         "purchasePrice": "475000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "11414",
#           "mainClass": "Wizard",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 2,
#           "statBoost1": "AGI",
#           "statBoost2": "END",
#           "subClass": "Priest",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636155638",
#         "id": "13346",
#         "purchasePrice": "219000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11643",
#           "mainClass": "Wizard",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "LCK",
#           "statBoost2": "END",
#           "subClass": "Warrior",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636155566",
#         "id": "13338",
#         "purchasePrice": "190000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11670",
#           "mainClass": "Archer",
#           "maxSummons": 4,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "DEX",
#           "statBoost2": "INT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636155535",
#         "id": "13339",
#         "purchasePrice": "250000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11305",
#           "mainClass": "Knight",
#           "maxSummons": 6,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "STR",
#           "statBoost2": "END",
#           "subClass": "Priest",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636155510",
#         "id": "13150",
#         "purchasePrice": "269000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "9032",
#           "mainClass": "Pirate",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "END",
#           "statBoost2": "AGI",
#           "subClass": "Wizard",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636155369",
#         "id": "12981",
#         "purchasePrice": "800000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "10618",
#           "mainClass": "Ninja",
#           "maxSummons": 5,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "AGI",
#           "statBoost2": "INT",
#           "subClass": "Priest",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636155228",
#         "id": "12969",
#         "purchasePrice": "220000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11213",
#           "mainClass": "Archer",
#           "maxSummons": 9,
#           "profession": "foraging",
#           "rarity": 0,
#           "statBoost1": "STR",
#           "statBoost2": "VIT",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636155157",
#         "id": "13337",
#         "purchasePrice": "186000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "9701",
#           "mainClass": "Wizard",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "VIT",
#           "statBoost2": "AGI",
#           "subClass": "Monk",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636154983",
#         "id": "13279",
#         "purchasePrice": "195000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "3759",
#           "mainClass": "Pirate",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "WIS",
#           "subClass": "Thief",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636154974",
#         "id": "13335",
#         "purchasePrice": "165000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11670",
#           "mainClass": "Archer",
#           "maxSummons": 4,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "DEX",
#           "statBoost2": "INT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636154919",
#         "id": "12501",
#         "purchasePrice": "650000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "9387",
#           "mainClass": "DarkKnight",
#           "maxSummons": 5,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "DEX",
#           "statBoost2": "END",
#           "subClass": "Priest",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636154759",
#         "id": "7993",
#         "purchasePrice": "350000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "3828",
#           "mainClass": "Priest",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "DEX",
#           "statBoost2": "AGI",
#           "subClass": "Wizard",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636154593",
#         "id": "13259",
#         "purchasePrice": "777000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11025",
#           "mainClass": "Ninja",
#           "maxSummons": 5,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "VIT",
#           "statBoost2": "WIS",
#           "subClass": "Pirate",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636154495",
#         "id": "13187",
#         "purchasePrice": "220000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11470",
#           "mainClass": "Priest",
#           "maxSummons": 9,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "WIS",
#           "statBoost2": "END",
#           "subClass": "Thief",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636154406",
#         "id": "13282",
#         "purchasePrice": "666000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11660",
#           "mainClass": "Summoner",
#           "maxSummons": 5,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "DEX",
#           "statBoost2": "INT",
#           "subClass": "Monk",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636154359",
#         "id": "12837",
#         "purchasePrice": "510000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "6450",
#           "mainClass": "Priest",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 2,
#           "statBoost1": "END",
#           "statBoost2": "STR",
#           "subClass": "Summoner",
#           "summons": 7
#         }
#       },
#       {
#         "endedAt": "1636154310",
#         "id": "13270",
#         "purchasePrice": "6400000000000000000000",
#         "tokenId": {
#           "generation": 0,
#           "id": "829",
#           "mainClass": "Pirate",
#           "maxSummons": 11,
#           "profession": "mining",
#           "rarity": 2,
#           "statBoost1": "WIS",
#           "statBoost2": "LCK",
#           "subClass": "Wizard",
#           "summons": 8
#         }
#       },
#       {
#         "endedAt": "1636154212",
#         "id": "12805",
#         "purchasePrice": "220000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11113",
#           "mainClass": "Monk",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "STR",
#           "statBoost2": "WIS",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636154082",
#         "id": "13162",
#         "purchasePrice": "245000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "5874",
#           "mainClass": "Warrior",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "LCK",
#           "statBoost2": "AGI",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636153846",
#         "id": "12841",
#         "purchasePrice": "205000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "7498",
#           "mainClass": "Archer",
#           "maxSummons": 6,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "WIS",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636153622",
#         "id": "13298",
#         "purchasePrice": "799000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "10830",
#           "mainClass": "Paladin",
#           "maxSummons": 2,
#           "profession": "fishing",
#           "rarity": 2,
#           "statBoost1": "END",
#           "statBoost2": "DEX",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636153394",
#         "id": "13289",
#         "purchasePrice": "265000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "10799",
#           "mainClass": "Wizard",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "INT",
#           "statBoost2": "DEX",
#           "subClass": "Priest",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636153374",
#         "id": "11456",
#         "purchasePrice": "505000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "10419",
#           "mainClass": "DarkKnight",
#           "maxSummons": 5,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "LCK",
#           "statBoost2": "AGI",
#           "subClass": "Thief",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636153018",
#         "id": "12371",
#         "purchasePrice": "275000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "4372",
#           "mainClass": "Monk",
#           "maxSummons": 9,
#           "profession": "gardening",
#           "rarity": 2,
#           "statBoost1": "LCK",
#           "statBoost2": "LCK",
#           "subClass": "Warrior",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636152889",
#         "id": "13287",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11509",
#           "mainClass": "Monk",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "WIS",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636152858",
#         "id": "12929",
#         "purchasePrice": "299000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "9736",
#           "mainClass": "Archer",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "WIS",
#           "statBoost2": "WIS",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636152786",
#         "id": "12932",
#         "purchasePrice": "220000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "9957",
#           "mainClass": "Wizard",
#           "maxSummons": 9,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "END",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636152784",
#         "id": "13273",
#         "purchasePrice": "260000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "9723",
#           "mainClass": "Thief",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 1,
#           "statBoost1": "INT",
#           "statBoost2": "END",
#           "subClass": "Thief",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636152674",
#         "id": "13195",
#         "purchasePrice": "235000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11570",
#           "mainClass": "Knight",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "END",
#           "subClass": "Warrior",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636152649",
#         "id": "13097",
#         "purchasePrice": "259000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11477",
#           "mainClass": "Thief",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "LCK",
#           "statBoost2": "WIS",
#           "subClass": "Monk",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636152624",
#         "id": "13293",
#         "purchasePrice": "190000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "11291",
#           "mainClass": "Pirate",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "DEX",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636152503",
#         "id": "13127",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11367",
#           "mainClass": "Thief",
#           "maxSummons": 7,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "WIS",
#           "statBoost2": "INT",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636152364",
#         "id": "13288",
#         "purchasePrice": "105000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "10584",
#           "mainClass": "Wizard",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "WIS",
#           "statBoost2": "STR",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636152154",
#         "id": "13284",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "9703",
#           "mainClass": "Monk",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "STR",
#           "statBoost2": "VIT",
#           "subClass": "Summoner",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636152092",
#         "id": "13285",
#         "purchasePrice": "195000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11664",
#           "mainClass": "Wizard",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "DEX",
#           "subClass": "Priest",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636151908",
#         "id": "13149",
#         "purchasePrice": "198000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11385",
#           "mainClass": "Archer",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "LCK",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636151766",
#         "id": "13268",
#         "purchasePrice": "250000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11579",
#           "mainClass": "Knight",
#           "maxSummons": 9,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "LCK",
#           "statBoost2": "END",
#           "subClass": "Warrior",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636151573",
#         "id": "13185",
#         "purchasePrice": "248000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "8906",
#           "mainClass": "Priest",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 1,
#           "statBoost1": "INT",
#           "statBoost2": "END",
#           "subClass": "Archer",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636151383",
#         "id": "13212",
#         "purchasePrice": "190000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "11582",
#           "mainClass": "Archer",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "AGI",
#           "subClass": "Priest",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636151077",
#         "id": "12432",
#         "purchasePrice": "777000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "10960",
#           "mainClass": "Monk",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 3,
#           "statBoost1": "END",
#           "statBoost2": "AGI",
#           "subClass": "Thief",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636151053",
#         "id": "13159",
#         "purchasePrice": "350000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "11018",
#           "mainClass": "Priest",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 2,
#           "statBoost1": "END",
#           "statBoost2": "DEX",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636150941",
#         "id": "13171",
#         "purchasePrice": "184000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "7384",
#           "mainClass": "Monk",
#           "maxSummons": 2,
#           "profession": "mining",
#           "rarity": 1,
#           "statBoost1": "WIS",
#           "statBoost2": "WIS",
#           "subClass": "Archer",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636150900",
#         "id": "13228",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "8924",
#           "mainClass": "Archer",
#           "maxSummons": 8,
#           "profession": "foraging",
#           "rarity": 0,
#           "statBoost1": "VIT",
#           "statBoost2": "AGI",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636150859",
#         "id": "13251",
#         "purchasePrice": "197000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "10996",
#           "mainClass": "Monk",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "WIS",
#           "statBoost2": "DEX",
#           "subClass": "Priest",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636150802",
#         "id": "11814",
#         "purchasePrice": "240000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "5608",
#           "mainClass": "Monk",
#           "maxSummons": 9,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "STR",
#           "statBoost2": "STR",
#           "subClass": "Wizard",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636150769",
#         "id": "13227",
#         "purchasePrice": "333000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "11016",
#           "mainClass": "Wizard",
#           "maxSummons": 7,
#           "profession": "foraging",
#           "rarity": 2,
#           "statBoost1": "AGI",
# ...
#           "statBoost2": "LCK",
#           "subClass": "Wizard",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636041637",
#         "id": "10333",
#         "purchasePrice": "5300000000000000000000",
#         "tokenId": {
#           "generation": 0,
#           "id": "307",
#           "mainClass": "Monk",
#           "maxSummons": 11,
#           "profession": "fishing",
#           "rarity": 3,
#           "statBoost1": "END",
#           "statBoost2": "INT",
#           "subClass": "Wizard",
#           "summons": 5
#         }
#       },
#       {
#         "endedAt": "1636041500",
#         "id": "10987",
#         "purchasePrice": "199000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "2225",
#           "mainClass": "Archer",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "STR",
#           "statBoost2": "END",
#           "subClass": "Pirate",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636041384",
#         "id": "11005",
#         "purchasePrice": "190000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "10492",
#           "mainClass": "Priest",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "DEX",
#           "statBoost2": "INT",
#           "subClass": "Archer",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636041364",
#         "id": "10189",
#         "purchasePrice": "190000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "4498",
#           "mainClass": "Pirate",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "VIT",
#           "statBoost2": "AGI",
#           "subClass": "Monk",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636041195",
#         "id": "7897",
#         "purchasePrice": "240000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "8616",
#           "mainClass": "Priest",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "STR",
#           "statBoost2": "WIS",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636041060",
#         "id": "10884",
#         "purchasePrice": "193000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "9332",
#           "mainClass": "Wizard",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "AGI",
#           "statBoost2": "WIS",
#           "subClass": "Warrior",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636041037",
#         "id": "10890",
#         "purchasePrice": "189000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "5902",
#           "mainClass": "Thief",
#           "maxSummons": 8,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "AGI",
#           "subClass": "Priest",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636040994",
#         "id": "5391",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "3885",
#           "mainClass": "Thief",
#           "maxSummons": 9,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "INT",
#           "statBoost2": "AGI",
#           "subClass": "Thief",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636040932",
#         "id": "9634",
#         "purchasePrice": "199000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "4321",
#           "mainClass": "Knight",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "INT",
#           "statBoost2": "INT",
#           "subClass": "Priest",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636040918",
#         "id": "5704",
#         "purchasePrice": "265000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "2446",
#           "mainClass": "Archer",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 2,
#           "statBoost1": "LCK",
#           "statBoost2": "VIT",
#           "subClass": "Knight",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636040662",
#         "id": "10799",
#         "purchasePrice": "300000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "6154",
#           "mainClass": "Warrior",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "WIS",
#           "statBoost2": "DEX",
#           "subClass": "Paladin",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636040642",
#         "id": "4156",
#         "purchasePrice": "185000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "6429",
#           "mainClass": "Monk",
#           "maxSummons": 8,
#           "profession": "foraging",
#           "rarity": 0,
#           "statBoost1": "VIT",
#           "statBoost2": "VIT",
#           "subClass": "Warrior",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636040611",
#         "id": "10967",
#         "purchasePrice": "198000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "9472",
#           "mainClass": "Priest",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "VIT",
#           "statBoost2": "STR",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636040595",
#         "id": "10940",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "7215",
#           "mainClass": "Priest",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "VIT",
#           "subClass": "Warrior",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636040578",
#         "id": "10927",
#         "purchasePrice": "195000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "7508",
#           "mainClass": "Pirate",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "DEX",
#           "statBoost2": "STR",
#           "subClass": "Warrior",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636040544",
#         "id": "10895",
#         "purchasePrice": "555000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "9270",
#           "mainClass": "DarkKnight",
#           "maxSummons": 5,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "DEX",
#           "statBoost2": "AGI",
#           "subClass": "Knight",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636040521",
#         "id": "10906",
#         "purchasePrice": "198000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "6902",
#           "mainClass": "Thief",
#           "maxSummons": 10,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "LCK",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636040510",
#         "id": "233",
#         "purchasePrice": "175000000000000000000",
#         "tokenId": {
#           "generation": 4,
#           "id": "7568",
#           "mainClass": "Priest",
#           "maxSummons": 4,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "VIT",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636040390",
#         "id": "10892",
#         "purchasePrice": "190000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "8843",
#           "mainClass": "Pirate",
#           "maxSummons": 9,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "STR",
#           "statBoost2": "END",
#           "subClass": "Thief",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636040374",
#         "id": "6608",
#         "purchasePrice": "210000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "4932",
#           "mainClass": "Knight",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "END",
#           "statBoost2": "AGI",
#           "subClass": "Wizard",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636040357",
#         "id": "10930",
#         "purchasePrice": "195000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "3788",
#           "mainClass": "Monk",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "VIT",
#           "statBoost2": "AGI",
#           "subClass": "Warrior",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636040332",
#         "id": "10959",
#         "purchasePrice": "193000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "9659",
#           "mainClass": "Monk",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 0,
#           "statBoost1": "INT",
#           "statBoost2": "LCK",
#           "subClass": "Wizard",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636040211",
#         "id": "10916",
#         "purchasePrice": "185000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "8869",
#           "mainClass": "Priest",
#           "maxSummons": 9,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "LCK",
#           "statBoost2": "INT",
#           "subClass": "Wizard",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636040153",
#         "id": "10776",
#         "purchasePrice": "210000000000000000000",
#         "tokenId": {
#           "generation": 4,
#           "id": "8119",
#           "mainClass": "Priest",
#           "maxSummons": 4,
#           "profession": "foraging",
#           "rarity": 2,
#           "statBoost1": "STR",
#           "statBoost2": "VIT",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636040008",
#         "id": "10848",
#         "purchasePrice": "320000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "7162",
#           "mainClass": "Monk",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 2,
#           "statBoost1": "WIS",
#           "statBoost2": "LCK",
#           "subClass": "Priest",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636039925",
#         "id": "9242",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "2576",
#           "mainClass": "Archer",
#           "maxSummons": 10,
#           "profession": "gardening",
#           "rarity": 1,
#           "statBoost1": "INT",
#           "statBoost2": "END",
#           "subClass": "Monk",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636039910",
#         "id": "7600",
#         "purchasePrice": "175000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "8791",
#           "mainClass": "Wizard",
#           "maxSummons": 6,
#           "profession": "foraging",
#           "rarity": 0,
#           "statBoost1": "STR",
#           "statBoost2": "AGI",
#           "subClass": "Knight",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636039876",
#         "id": "10577",
#         "purchasePrice": "899000000000000000000",
#         "tokenId": {
#           "generation": 6,
#           "id": "10210",
#           "mainClass": "Paladin",
#           "maxSummons": 1,
#           "profession": "mining",
#           "rarity": 0,
#           "statBoost1": "END",
#           "statBoost2": "STR",
#           "subClass": "Pirate",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636039853",
#         "id": "228",
#         "purchasePrice": "175000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "6389",
#           "mainClass": "Pirate",
#           "maxSummons": 7,
#           "profession": "foraging",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "END",
#           "subClass": "Archer",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636039761",
#         "id": "8004",
#         "purchasePrice": "278000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "9357",
#           "mainClass": "Warrior",
#           "maxSummons": 9,
#           "profession": "fishing",
#           "rarity": 2,
#           "statBoost1": "STR",
#           "statBoost2": "VIT",
#           "subClass": "Knight",
#           "summons": 0
#         }
#       },
#       {
#         "endedAt": "1636039594",
#         "id": "8729",
#         "purchasePrice": "200000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "5351",
#           "mainClass": "Archer",
#           "maxSummons": 10,
#           "profession": "fishing",
#           "rarity": 1,
#           "statBoost1": "VIT",
#           "statBoost2": "DEX",
#           "subClass": "Knight",
#           "summons": 3
#         }
#       },
#       {
#         "endedAt": "1636039520",
#         "id": "10950",
#         "purchasePrice": "160000000000000000000",
#         "tokenId": {
#           "generation": 3,
#           "id": "6290",
#           "mainClass": "Archer",
#           "maxSummons": 8,
#           "profession": "gardening",
#           "rarity": 0,
#           "statBoost1": "DEX",
#           "statBoost2": "AGI",
#           "subClass": "Warrior",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636039379",
#         "id": "10911",
#         "purchasePrice": "170000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "5773",
#           "mainClass": "Wizard",
#           "maxSummons": 8,
#           "profession": "fishing",
#           "rarity": 0,
#           "statBoost1": "AGI",
#           "statBoost2": "END",
#           "subClass": "Archer",
#           "summons": 2
#         }
#       },
#       {
#         "endedAt": "1636039329",
#         "id": "10919",
#         "purchasePrice": "170000000000000000000",
#         "tokenId": {
#           "generation": 2,
#           "id": "7900",
#           "mainClass": "Thief",
#           "maxSummons": 4,
#           "profession": "foraging",
#           "rarity": 1,
#           "statBoost1": "INT",
#           "statBoost2": "END",
#           "subClass": "Wizard",
#           "summons": 1
#         }
#       },
#       {
#         "endedAt": "1636039245",
#         "id": "10827",
#         "purchasePrice": "2980000000000000000000",
#         "tokenId": {
#           "generation": 0,
#           "id": "1591",
#           "mainClass": "Thief",
#           "maxSummons": 11,
#           "profession": "gardening",
#           "rarity": 2,
#           "statBoost1": "STR",
#           "statBoost2": "LCK",
#           "subClass": "Wizard",
#           "summons": 15
#         }
#       },
#       {
#         "endedAt": "1636039176",
#         "id": "10853",
#         "purchasePrice": "230000000000000000000",
#         "tokenId": {
#           "generation": 1,
#           "id": "2096",
#           "mainClass": "Archer",
#           "maxSummons": 10,
#           "profession": "foraging",
#           "rarity": 2,
#           "statBoost1": "VIT",
#           "statBoost2": "VIT",
#           "subClass": "Priest",
#           "summons": 2
#         }
#       }
#     ]
#   }
# }

# %%
json_data = json.loads(r.text)

# %%
df_data = json_data['data']['saleAuctions']
df = pd.DataFrame(df_data)

# %%
df.head()
# Out:
#       endedAt     id          purchasePrice  \
# 0  1636166259  13449  195000000000000000000
# 1  1636166120  13368  194000000000000000000
# 2  1636165776   7901  888000000000000000000
# 3  1636165675  13304  249000000000000000000
# 4  1636165668  13543  210000000000000000000
#
#                                              tokenId
# 0  {'generation': 4, 'id': '11450', 'mainClass': ...
# 1  {'generation': 2, 'id': '11658', 'mainClass': ...
# 2  {'generation': 2, 'id': '9527', 'mainClass': '...
# 3  {'generation': 1, 'id': '7653', 'mainClass': '...
# 4  {'generation': 2, 'id': '10975', 'mainClass': ...

# %%
df['tokenId'].apply(pd.Series)
# Out:
#      generation     id mainClass  maxSummons profession  rarity statBoost1  \
# 0             4  11450      Monk           4     mining       0        STR
# 1             2  11658    Pirate           8  gardening       0        LCK
# 2             2   9527    Knight           8  gardening       3        WIS
# 3             1   7653    Priest          10    fishing       0        WIS
# 4             2  10975    Priest           9     mining       1        AGI
# ..          ...    ...       ...         ...        ...     ...        ...
# 995           3   6290    Archer           8  gardening       0        DEX
# 996           2   5773    Wizard           8    fishing       0        AGI
# 997           2   7900     Thief           4   foraging       1        INT
# 998           0   1591     Thief          11  gardening       2        STR
# 999           1   2096    Archer          10   foraging       2        VIT
#
#     statBoost2 subClass  summons
# 0          VIT   Knight        0
# 1          WIS    Thief        0
# 2          INT    Thief        0
# 3          VIT   Pirate        0
# 4          STR     Monk        0
# ..         ...      ...      ...
# 995        AGI  Warrior        2
# 996        END   Archer        2
# 997        END   Wizard        1
# 998        LCK   Wizard       15
# 999        VIT   Priest        2
#
# [1000 rows x 10 columns]

# %%
df2 = df['tokenId'].apply(pd.Series)

# %%
df2 = pd.concat([df2, df['purchasePrice']], axis=1)
df2 = pd.concat([df2, df['endedAt']], axis=1)
df2.head()
# Out:
#    generation     id mainClass  maxSummons profession  rarity statBoost1  \
# 0           4  11450      Monk           4     mining       0        STR
# 1           2  11658    Pirate           8  gardening       0        LCK
# 2           2   9527    Knight           8  gardening       3        WIS
# 3           1   7653    Priest          10    fishing       0        WIS
# 4           2  10975    Priest           9     mining       1        AGI
#
#   statBoost2 subClass  summons          purchasePrice     endedAt
# 0        VIT   Knight        0  195000000000000000000  1636166259
# 1        WIS    Thief        0  194000000000000000000  1636166120
# 2        INT    Thief        0  888000000000000000000  1636165776
# 3        VIT   Pirate        0  249000000000000000000  1636165675
# 4        STR     Monk        0  210000000000000000000  1636165668

# %%
#df2 = pd.concat([df['tokenId'].apply(pd.Series), df['purchasePrice']], axis=1)
#df2 = pd.concat([df['tokenId'].apply(pd.Series), df['endedAt']], axis=1)

# %%
cols = ['id', 'rarity', 'generation', 'mainClass', 'subClass', 'statBoost1', 'statBoost2', 'profession', 'summons', 'maxSummons', 'purchasePrice', 'endedAt']

# %%
df2 = df2.reindex(columns=cols)

# %%
df2['rarity'] = df2['rarity'].replace([0, 1, 2, 3, 4], ['common', 'uncommon', 'rare', 'legendary', 'mythic'])
#print(df2)

# %%
df2.head()
# Out:
#       id     rarity  generation mainClass subClass statBoost1 statBoost2  \
# 0  11450     common           4      Monk   Knight        STR        VIT
# 1  11658     common           2    Pirate    Thief        LCK        WIS
# 2   9527  legendary           2    Knight    Thief        WIS        INT
# 3   7653     common           1    Priest   Pirate        WIS        VIT
# 4  10975   uncommon           2    Priest     Monk        AGI        STR
#
#   profession  summons  maxSummons          purchasePrice     endedAt
# 0     mining        0           4  195000000000000000000  1636166259
# 1  gardening        0           8  194000000000000000000  1636166120
# 2  gardening        0           8  888000000000000000000  1636165776
# 3    fishing        0          10  249000000000000000000  1636165675
# 4     mining        0           9  210000000000000000000  1636165668

# %%
soldPrice = []

for x in df['purchasePrice']:
    for y in x:
        priceLen = len(x)-18
    x = x[: priceLen]
    #x = int(x)
    soldPrice.append(x)

# %%
df2['soldPrice'] = soldPrice
df2 = df2.drop(['purchasePrice'], axis=1)

# %%
df2.head()
# Out:
#       id     rarity  generation mainClass subClass statBoost1 statBoost2  \
# 0  11450     common           4      Monk   Knight        STR        VIT
# 1  11658     common           2    Pirate    Thief        LCK        WIS
# 2   9527  legendary           2    Knight    Thief        WIS        INT
# 3   7653     common           1    Priest   Pirate        WIS        VIT
# 4  10975   uncommon           2    Priest     Monk        AGI        STR
#
#   profession  summons  maxSummons     endedAt soldPrice
# 0     mining        0           4  1636166259       195
# 1  gardening        0           8  1636166120       194
# 2  gardening        0           8  1636165776       888
# 3    fishing        0          10  1636165675       249
# 4     mining        0           9  1636165668       210

# %%
genstr = []

for x in df2['generation']:
    x = str(x)
    genstr.append(x)
    
df2['generation'] = genstr

# %%
utcTime = []

for x in df['endedAt']:
    x = int(x)
    x = datetime.datetime.fromtimestamp(int(x)).strftime('%Y-%m-%d %H:%M:%S')
    utcTime.append(x)
    #print(utcTime)
    
df2['timeStamp'] = utcTime
#df2 = df2.drop(['endedAt'], axis=1)

# %%
#filter

#df2[(df2['generation']==1) & (df2['rarity']=='uncommon')]
#df[(df["a"] > 2) & (df["b"] > 5)]

# gen0 = df2[(df2['generation']==0)]
# gen1 = df2[(df2['generation']==1)]
# gen2 = df2[(df2['generation']==2)]
# gen3 = df2[(df2['generation']==3)]
# gen4 = df2[(df2['generation']==4)]
# genbeyond = df2[(df2['generation']>4)]

#warrior = df2[(df2['mainClass']=='Warrior') & (df2["generation"]=='1')]
knight = df2[(df2['mainClass']=='Knight') & (df2["generation"]=='1')]

#fishing = df2[(df2['profession']=='fishing') & (df2["generation"]=='1')]

warriorC = df2[(df2['mainClass']=='Warrior') & (df2["rarity"]=='common')]
warriorU = df2[(df2['mainClass']=='Warrior') & (df2["rarity"]=='uncommon')]
warriorR = df2[(df2['mainClass']=='Warrior') & (df2["rarity"]=='rare')]
warriorL = df2[(df2['mainClass']=='Warrior') & (df2["rarity"]=='legendary')]
warriorM = df2[(df2['mainClass']=='Warrior') & (df2["rarity"]=='mythic')]


# warriorC = df2[(df2["rarity"]=='common')]
# warriorU = df2[(df2["rarity"]=='uncommon')]
# warriorR = df2[(df2["rarity"]=='rare')]
# warriorL = df2[(df2["rarity"]=='legendary')]
# warriorM = df2[(df2["rarity"]=='mythic')]

# %%
df2.to_excel("tavern_extract.xlsx", index=False)

# %%
# visualization

warriorC.head()
# Out:
#        id  rarity generation mainClass subClass statBoost1 statBoost2  \
# 14   6047  common          1   Warrior   Archer        WIS        WIS
# 26  11767  common          2   Warrior    Thief        INT        WIS
# 27  11286  common          2   Warrior   Archer        WIS        DEX
# 61  11117  common          2   Warrior    Ninja        WIS        INT
# 81   5874  common          1   Warrior     Monk        LCK        AGI
#
#    profession  summons  maxSummons     endedAt soldPrice            timeStamp
# 14  gardening        2          10  1636165257       206  2021-11-05 21:20:57
# 26  gardening        0           8  1636163051       180  2021-11-05 20:44:11
# 27     mining        0           9  1636163017       234  2021-11-05 20:43:37
# 61    fishing        1           8  1636155855       225  2021-11-05 18:44:15
# 81  gardening        0          10  1636154082       245  2021-11-05 18:14:42

# %%
app = dash.Dash(__name__)

# %%
#sns.set_style("whitegrid")

#fig, ax = plt.subplots()
#fig.set_size_inches(15, 15)
#sns.boxplot(x="mainClass", y="soldPrice", data=fishing, hue='rarity', hue_order=['common', 'uncommon', 'rare', 'legendary', 'mythic'], palette='rainbow')

#fig.tight_layout()
#plt.savefig('save_as_a_png.png')

# %%
app.layout = html.Div(
    children=[
        html.H1(children="DeFi Kingdom Tavern Dashboard",),
        html.P(
            children="Random dashboards for tavern interactions",
        ),
        
#fig = go.Figure()

 px.scatter(warriorC, x="timeStamp", y="soldPrice",
                 hover_name="id", hover_data={'rarity'})])

# fig.add_trace(go.Scatter(x=warriorC.timeStamp, y=warriorC.soldPrice, mode='markers', name='Common',
#                         hovertemplate =
#     '<b>ID</b>: %{text}<br>' +
#     '<b>Price</b>: %{y} Jewels'+
#     '<br><b>Sold At</b>: %{x} UTC<br><extra></extra>',
#      text = warriorC['id'] + '<br>' + 
#             '<b>Rarity</b>: ' + warriorC['rarity'] + '<br>' + 
#             '<b>Generation</b>: ' + warriorC['generation'] + '<br>' + '<br>' + 
#             '<b>Main Class</b>: ' + warriorC['mainClass'] + '<br>' +
#             '<b>Sub Class</b>: ' + warriorC['subClass'] + '<br>' + 
#             '<b>Primary Boost</b>: ' + warriorC['statBoost1'] + '<br>' +
#             '<b>Secondary Boost</b>: ' + warriorC['statBoost2'] + '<br>' + 
#             '<b>Profession</b>: ' + warriorC['profession']+ '<br>',
#      marker = dict(color='rgba(219, 217, 222, 1)', size=7)
     
#             ))

# fig.add_trace(go.Scatter(x=warriorU.timeStamp, y=warriorU.soldPrice, mode='markers', name='Uncommon',
#                         hovertemplate =
#     '<b>ID</b>: %{text}<br>' +
#     '<b>Price</b>: %{y} Jewels'+
#     '<br><b>Sold At</b>: %{x} UTC<br><extra></extra>',
#      text = warriorU['id'] + '<br>' + 
#             '<b>Rarity</b>: ' + warriorU['rarity'] + '<br>' +
#             '<b>Generation</b>: ' + warriorU['generation'] + '<br>' + '<br>' + 
#             '<b>Main Class</b>: ' + warriorU['mainClass'] + '<br>' +
#             '<b>Sub Class</b>: ' + warriorU['subClass'] + '<br>' + 
#             '<b>Primary Boost</b>: ' + warriorU['statBoost1'] + '<br>' +
#             '<b>Secondary Boost</b>: ' + warriorU['statBoost2'] + '<br>' + 
#             '<b>Profession</b>: ' + warriorU['profession']+ '<br>',
#      marker = dict(color='rgba(115, 191, 131, 1)', size=7)
#             ))

# fig.add_trace(go.Scatter(x=warriorR.timeStamp, y=warriorR.soldPrice, mode='markers', name='Rare',
#                         hovertemplate =
#     '<b>ID</b>: %{text}<br>' +
#     '<b>Price</b>: %{y} Jewels'+
#     '<br><b>Sold At</b>: %{x} UTC<br><extra></extra>',
#      text = warriorR['id'] + '<br>' + 
#             '<b>Rarity</b>: ' + warriorR['rarity'] + '<br>' +
#             '<b>Generation</b>: ' + warriorR['generation'] + '<br>' + '<br>' + 
#             '<b>Main Class</b>: ' + warriorR['mainClass'] + '<br>' +
#             '<b>Sub Class</b>: ' + warriorR['subClass'] + '<br>' + 
#             '<b>Primary Boost</b>: ' + warriorR['statBoost1'] + '<br>' +
#             '<b>Secondary Boost</b>: ' + warriorR['statBoost2'] + '<br>' + 
#             '<b>Profession</b>: ' + warriorR['profession']+ '<br>',
#     marker = dict(color='rgba(53, 147, 183, 1)', size=7)
#             ))

# fig.add_trace(go.Scatter(x=warriorL.timeStamp, y=warriorL.soldPrice, mode='markers', name='Legendary',
#                         hovertemplate =
#     '<b>ID</b>: %{text}<br>' +
#     '<b>Price</b>: %{y} Jewels'+
#     '<br><b>Sold At</b>: %{x} UTC<br><extra></extra>',
#      text = warriorL['id'] + '<br>' + 
#             '<b>Rarity</b>: ' + warriorL['rarity'] + '<br>' +
#             '<b>Generation</b>: ' + warriorL['generation'] + '<br>' + '<br>' + 
#             '<b>Main Class</b>: ' + warriorL['mainClass'] + '<br>' +
#             '<b>Sub Class</b>: ' + warriorL['subClass'] + '<br>' + 
#             '<b>Primary Boost</b>: ' + warriorL['statBoost1'] + '<br>' +
#             '<b>Secondary Boost</b>: ' + warriorL['statBoost2'] + '<br>' + 
#             '<b>Profession</b>: ' + warriorL['profession']+ '<br>',
#     marker = dict(color='rgba(255, 164, 62, 1)', size=7)
#             ))

# fig.add_trace(go.Scatter(x=warriorM.timeStamp, y=warriorM.soldPrice, mode='markers', name='Mythic',
#                         hovertemplate =
#     '<b>ID</b>: %{text}<br>' +
#     '<b>Price</b>: %{y} Jewels'+
#     '<br><b>Sold At</b>: %{x} UTC<br><extra></extra>',
#      text = warriorM['id'] + '<br>' + 
#             '<b>Rarity</b>: ' + warriorM['rarity'] + '<br>' +
#             '<b>Generation</b>: ' + warriorM['generation'] + '<br>' + '<br>' + 
#             '<b>Main Class</b>: ' + warriorM['mainClass'] + '<br>' +
#             '<b>Sub Class</b>: ' + warriorM['subClass'] + '<br>' + 
#             '<b>Primary Boost</b>: ' + warriorM['statBoost1'] + '<br>' +
#             '<b>Secondary Boost</b>: ' + warriorM['statBoost2'] + '<br>' + 
#             '<b>Profession</b>: ' + warriorM['profession']+ '<br>',
#     marker = dict(color='rgba(178, 109, 216, 1)', size=7)          
#             ))

# fig.update_traces(marker=dict(line=dict(width=.5)))
# fig.update_layout(title='Latest Warriors Sold Based on Last 1000 Tavern Sales', 
#                   titlefont=dict(family='Arial', size=24),
#                   xaxis=dict(showgrid=True, ticks='outside'), 
#                   xaxis_title='Date in UTC',
#                   yaxis_title='Jewel',
#                   plot_bgcolor='white'
#                  )

# fig.update_xaxes(showspikes=True)
# fig.update_yaxes(showspikes=True)

                  #plot_bgcolor='white')

        
if __name__ == "__main__":
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)

# %%
fig = go.Figure()

# fig = px.scatter(warrior, x="timeStamp", y="soldPrice",
#                  hover_name="id", hover_data=
#                  {'rarity'},
#                 )
                 
                 
                 
                 #"rarity", "soldPrice"])

fig.add_trace(go.Scatter(x=warriorC.timeStamp, y=warriorC.soldPrice, mode='markers', name='Common',
                        hovertemplate =
    '<b>ID</b>: %{text}<br>' +
    '<b>Price</b>: %{y} Jewels'+
    '<br><b>Sold At</b>: %{x} UTC<br><extra></extra>',
     text = warriorC['id'] + '<br>' + 
            '<b>Rarity</b>: ' + warriorC['rarity'] + '<br>' + 
            '<b>Generation</b>: ' + warriorC['generation'] + '<br>' + '<br>' + 
            '<b>Main Class</b>: ' + warriorC['mainClass'] + '<br>' +
            '<b>Sub Class</b>: ' + warriorC['subClass'] + '<br>' + 
            '<b>Primary Boost</b>: ' + warriorC['statBoost1'] + '<br>' +
            '<b>Secondary Boost</b>: ' + warriorC['statBoost2'] + '<br>' + 
            '<b>Profession</b>: ' + warriorC['profession']+ '<br>',
     marker = dict(color='rgba(219, 217, 222, 1)', size=7)
     
            ))

fig.add_trace(go.Scatter(x=warriorU.timeStamp, y=warriorU.soldPrice, mode='markers', name='Uncommon',
                        hovertemplate =
    '<b>ID</b>: %{text}<br>' +
    '<b>Price</b>: %{y} Jewels'+
    '<br><b>Sold At</b>: %{x} UTC<br><extra></extra>',
     text = warriorU['id'] + '<br>' + 
            '<b>Rarity</b>: ' + warriorU['rarity'] + '<br>' +
            '<b>Generation</b>: ' + warriorU['generation'] + '<br>' + '<br>' + 
            '<b>Main Class</b>: ' + warriorU['mainClass'] + '<br>' +
            '<b>Sub Class</b>: ' + warriorU['subClass'] + '<br>' + 
            '<b>Primary Boost</b>: ' + warriorU['statBoost1'] + '<br>' +
            '<b>Secondary Boost</b>: ' + warriorU['statBoost2'] + '<br>' + 
            '<b>Profession</b>: ' + warriorU['profession']+ '<br>',
     marker = dict(color='rgba(115, 191, 131, 1)', size=7)
            ))

fig.add_trace(go.Scatter(x=warriorR.timeStamp, y=warriorR.soldPrice, mode='markers', name='Rare',
                        hovertemplate =
    '<b>ID</b>: %{text}<br>' +
    '<b>Price</b>: %{y} Jewels'+
    '<br><b>Sold At</b>: %{x} UTC<br><extra></extra>',
     text = warriorR['id'] + '<br>' + 
            '<b>Rarity</b>: ' + warriorR['rarity'] + '<br>' +
            '<b>Generation</b>: ' + warriorR['generation'] + '<br>' + '<br>' + 
            '<b>Main Class</b>: ' + warriorR['mainClass'] + '<br>' +
            '<b>Sub Class</b>: ' + warriorR['subClass'] + '<br>' + 
            '<b>Primary Boost</b>: ' + warriorR['statBoost1'] + '<br>' +
            '<b>Secondary Boost</b>: ' + warriorR['statBoost2'] + '<br>' + 
            '<b>Profession</b>: ' + warriorR['profession']+ '<br>',
    marker = dict(color='rgba(53, 147, 183, 1)', size=7)
            ))

fig.add_trace(go.Scatter(x=warriorL.timeStamp, y=warriorL.soldPrice, mode='markers', name='Legendary',
                        hovertemplate =
    '<b>ID</b>: %{text}<br>' +
    '<b>Price</b>: %{y} Jewels'+
    '<br><b>Sold At</b>: %{x} UTC<br><extra></extra>',
     text = warriorL['id'] + '<br>' + 
            '<b>Rarity</b>: ' + warriorL['rarity'] + '<br>' +
            '<b>Generation</b>: ' + warriorL['generation'] + '<br>' + '<br>' + 
            '<b>Main Class</b>: ' + warriorL['mainClass'] + '<br>' +
            '<b>Sub Class</b>: ' + warriorL['subClass'] + '<br>' + 
            '<b>Primary Boost</b>: ' + warriorL['statBoost1'] + '<br>' +
            '<b>Secondary Boost</b>: ' + warriorL['statBoost2'] + '<br>' + 
            '<b>Profession</b>: ' + warriorL['profession']+ '<br>',
    marker = dict(color='rgba(255, 164, 62, 1)', size=7)
            ))

fig.add_trace(go.Scatter(x=warriorM.timeStamp, y=warriorM.soldPrice, mode='markers', name='Mythic',
                        hovertemplate =
    '<b>ID</b>: %{text}<br>' +
    '<b>Price</b>: %{y} Jewels'+
    '<br><b>Sold At</b>: %{x} UTC<br><extra></extra>',
     text = warriorM['id'] + '<br>' + 
            '<b>Rarity</b>: ' + warriorM['rarity'] + '<br>' +
            '<b>Generation</b>: ' + warriorM['generation'] + '<br>' + '<br>' + 
            '<b>Main Class</b>: ' + warriorM['mainClass'] + '<br>' +
            '<b>Sub Class</b>: ' + warriorM['subClass'] + '<br>' + 
            '<b>Primary Boost</b>: ' + warriorM['statBoost1'] + '<br>' +
            '<b>Secondary Boost</b>: ' + warriorM['statBoost2'] + '<br>' + 
            '<b>Profession</b>: ' + warriorM['profession']+ '<br>',
    marker = dict(color='rgba(178, 109, 216, 1)', size=7)          
            ))

fig.update_traces(marker=dict(line=dict(width=.5)))
fig.update_layout(title='Latest Warriors Sold Based on Last 1000 Tavern Sales', 
                  titlefont=dict(family='Arial', size=24),
                  xaxis=dict(showgrid=True, ticks='outside'), 
                  xaxis_title='Date in UTC',
                  yaxis_title='Jewel',
                  plot_bgcolor='white'
                 )

fig.update_xaxes(showspikes=True)
fig.update_yaxes(showspikes=True)

                  #plot_bgcolor='white')

# %%
sns.set_theme()
fig, ax = plt.subplots()
fig.set_size_inches(8, 8)
sns.boxplot(x="profession", y="soldPrice", data=knight, hue='rarity', hue_order=['common', 'uncommon', 'rare', 'legendary', 'mythic'], palette='rainbow')
